# %%
import sys
sys.path.append("/home/michal/personal/programming/set-solve")
import cv2

from pathlib import Path

import segmentation
import utils

# %%
# 1 -> rename files in data folder
root_dir = Path(".").resolve().parent
data_dir = root_dir / "data" / "input"
output_test = root_dir / "data" / "preprocess-blurred"
img_test = cv2.imread(str(data_dir / "8.jpg"), cv2.IMREAD_COLOR)

# %%
utils.cv2_imshow(img_test)

# %%
cards = segmentation.detect_cards(img_test)

# %%
for card in cards:
    utils.cv2_imshow(card.img_bgr)
    print(card.rect)
# Out:
# [[ 917 1355]
#  [1297 1359]
#  [1302 1929]
#  [ 906 1931]]
# [[ 429 1418]
#  [ 819 1412]
#  [ 824 1990]
#  [ 415 2005]]
# [[2003 1403]
#  [2370 1412]
#  [2402 1974]
#  [2019 1968]]
# [[1622 2906]
#  [2030 2927]
#  [2024 3631]
#  [1590 3610]]
# [[ 382 2096]
#  [ 793 2071]
#  [ 808 2707]
#  [ 380 2740]]
# [[2234 2855]
#  [2636 2891]
#  [2634 3580]
#  [2211 3546]]
# [[ 920 2129]
#  [1315 2060]
#  [1421 2678]
#  [1010 2760]]
# [[1466 1385]
#  [1837 1366]
#  [1892 1928]
#  [1508 1953]]
# [[ 965 2928]
#  [1377 2833]
#  [1515 3514]
#  [1086 3626]]
# [[2039 2154]
#  [2414 2088]
#  [2563 2696]
#  [2176 2772]]
# [[1426 2041]
#  [1809 1998]
#  [1902 2609]
#  [1500 2662]]
# [[ 334 2989]
#  [ 768 2930]
#  [ 814 3646]
#  [ 357 3712]]
